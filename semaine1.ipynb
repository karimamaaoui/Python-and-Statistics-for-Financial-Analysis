# %%
import pandas as pd
fb = pd.read_csv('./data/facebook.csv')
print(fb)
# Out:
#            Date        Open        High         Low       Close   Adj Close  \
# 0    2014-12-31   20.400000   20.510000   19.990000   20.049999   19.459270
# 1    2015-01-02   20.129999   20.280001   19.809999   20.129999   19.536913
# 2    2015-01-05   20.129999   20.190001   19.700001   19.790001   19.206934
# 3    2015-01-06   19.820000   19.840000   19.170000   19.190001   18.624611
# 4    2015-01-07   19.330000   19.500000   19.080000   19.139999   18.576082
# ..          ...         ...         ...         ...         ...         ...
# 775  2018-01-30  241.110001  246.419998  238.410004  242.720001  242.720001
# 776  2018-01-31  245.770004  249.270004  244.449997  245.800003  245.800003
# 777  2018-02-01  238.520004  246.899994  238.059998  240.500000  240.500000
# 778  2018-02-02  237.000000  237.970001  231.169998  233.520004  233.520004
# 779  2018-02-05  227.000000  233.229996  205.000000  213.699997  213.699997
#
#        Volume
# 0     4157500
# 1     2842000
# 2     4948800
# 3     4944100
# 4     8045200
# ..        ...
# 775  14270800
# 776  11964400
# 777  12980600
# 778  17961600
# 779  28869000
#
# [780 rows x 7 columns]

# %%
print(type(fb))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
ms = None

# %%
# run this cell to ensure Microsoft's stock data is imported
print(ms.iloc[0, 0])
# Out:
# 19.99

# %%
print(ms.iloc[0, 0])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In [15], line 1
# ----> 1 print(ms.iloc[0, 0])
#
# AttributeError: 'NoneType' object has no attribute 'iloc'

# %%
print(fb.iloc[0, 4])
# Out:
# 20.049999

# %%
fb.head()
# Out:
#          Date       Open       High        Low      Close  Adj Close   Volume
# 0  2014-12-31  20.400000  20.510000  19.990000  20.049999  19.459270  4157500
# 1  2015-01-02  20.129999  20.280001  19.809999  20.129999  19.536913  2842000
# 2  2015-01-05  20.129999  20.190001  19.700001  19.790001  19.206934  4948800
# 3  2015-01-06  19.820000  19.840000  19.170000  19.190001  18.624611  4944100
# 4  2015-01-07  19.330000  19.500000  19.080000  19.139999  18.576082  8045200

# %%
fb.shape
# Out:
# (780, 7)

# %%
print(fb.shape)
# Out:
# (730, 16)

# %%
print(fb.columns)
# Out:
# Index(['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume',
#        'PriceDiff', 'Direction', 'ma50', 'MA10', 'MA50', 'Shares', 'Close1',
#        'Profit', 'wealth'],
#       dtype='object')

# %%
# print summary statistics of Facebook
print(fb.describe())
# Out:
#              Open        High         Low       Close   Adj Close  \
# count  780.000000  780.000000  780.000000  780.000000  780.000000
# mean    80.212705   81.285654   79.022397   80.264897   79.914215
# std     64.226121   65.048907   63.190963   64.198375   64.327846
# min     19.250000   19.500000   18.940001   19.139999   18.576082
# 25%     25.525000   26.085000   24.845000   25.475000   25.134512
# 50%     53.379999   54.034999   52.930000   53.420000   53.035403
# 75%    113.322502  115.779999  110.297499  113.702501  113.261238
# max    245.770004  249.270004  244.449997  246.850006  246.850006
#
#              Volume
# count  7.800000e+02
# mean   1.204453e+07
# std    8.221848e+06
# min    1.311200e+06
# 25%    7.215200e+06
# 50%    9.728700e+06
# 75%    1.408885e+07
# max    9.232320e+07

# %%
## Locate a particular row of data using "Selection by label"

# %%
# select all the information of Facebook in 2015.

fb['Date'] = pd.to_datetime(fb['Date'], format='%Y-%m-%d')  
# Filter data between two dates
filtered_df = fb.loc[(fb['Date'] >= '2015-01-01')
                     & (fb['Date'] < '2015-12-31')]
# Display
filtered_df
# Out:
#           Date       Open       High        Low      Close  Adj Close   Volume
# 1   2015-01-02  20.129999  20.280001  19.809999  20.129999  19.536913  2842000
# 2   2015-01-05  20.129999  20.190001  19.700001  19.790001  19.206934  4948800
# 3   2015-01-06  19.820000  19.840000  19.170000  19.190001  18.624611  4944100
# 4   2015-01-07  19.330000  19.500000  19.080000  19.139999  18.576082  8045200
# 5   2015-01-08  19.360001  19.980000  19.350000  19.860001  19.274870  7094500
# ..         ...        ...        ...        ...        ...        ...      ...
# 247 2015-12-23  32.980000  33.189999  32.919998  33.060001  32.618134  3063100
# 248 2015-12-24  32.959999  33.250000  32.910000  33.169998  32.726662  1311200
# 249 2015-12-28  32.820000  33.139999  32.360001  33.139999  32.697067  3550600
# 250 2015-12-29  33.160000  33.779999  33.070000  33.680000  33.229843  5091500
# 251 2015-12-30  33.650002  33.939999  33.380001  33.389999  32.943722  4508600
#
# [251 rows x 7 columns]

# %%
fb.tail()
# Out:
#            Date        Open        High         Low       Close   Adj Close  \
# 775  2018-01-30  241.110001  246.419998  238.410004  242.720001  242.720001
# 776  2018-01-31  245.770004  249.270004  244.449997  245.800003  245.800003
# 777  2018-02-01  238.520004  246.899994  238.059998  240.500000  240.500000
# 778  2018-02-02  237.000000  237.970001  231.169998  233.520004  233.520004
# 779  2018-02-05  227.000000  233.229996  205.000000  213.699997  213.699997
#
#        Volume
# 775  14270800
# 776  11964400
# 777  12980600
# 778  17961600
# 779  28869000

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
plt.figure(figsize=(10, 8))
fb['Close'].plot()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
fb = pd.read_csv('./data/facebook.csv')
ms =  pd.read_csv('./data/microsoft.csv')

# %%
## Create a new column in the DataFrame (1) - Price difference

# %%
#Create a new column PriceDiff in the DataFrame fb
fb['PriceDiff'] = fb['Close'].shift(-1) - fb['Close']
print(fb['PriceDiff'])

# %%
ms['PriceDiff'] = ms['Close'].shift(-1) - ms['Close']
print(ms['PriceDiff'])
# Out:
# 0      0.309997
# 1     -0.429996
# 2     -0.680000
# 3      0.579998
# 4      1.360000
#          ...
# 775    2.270004
# 776   -0.750000
# 777   -2.480003
# 778   -3.779999
# 779         NaN
# Name: PriceDiff, Length: 780, dtype: float64

# %%
#Run this code to display the price difference of Microsoft on 2015-01-05
ms['Date'] = pd.to_datetime(ms['Date'], format='%Y-%m-%d')  
# Filter data between two dates
filtered_df = ms.loc[(ms['Date'] == '2015-01-05'),"PriceDiff"]
# Display
filtered_df

#print(ms['PriceDiff'].loc['2015-01-05'])

# %%
## Create a new column in the DataFrame using List Comprehension - Direction

# %%
#Create a new column Direction. 
#The List Comprehension means : if the price difference is larger than 0, denote as 1, otherwise, denote as 0,
#for every record in the DataFrame - fb
fb['Direction'] = [1 if fb['PriceDiff'].loc[ei] > 0 else 0 for ei in fb.index ]
print(fb['Direction'])
# Out:
# 0      1
# 1      0
# 2      0
# 3      0
# 4      1
#       ..
# 775    1
# 776    0
# 777    0
# 778    0
# 779    0
# Name: Direction, Length: 780, dtype: int64

# %%
ms['Direction'] = None

# %%
# Run the following code to show the price difference on 2015-01-05

ms['Date'] = pd.to_datetime(ms['Date'], format='%Y-%m-%d')  
filtered_df = (ms['PriceDiff'].loc[(ms['Date'] == '2015-01-05')], ms['Direction'].loc[(ms['Date'] == '2015-01-05')])
filtered_df
# Out:
# (2   -0.68
#  Name: PriceDiff, dtype: float64,
#  2    None
#  Name: Direction, dtype: object)

# %%
fb['ma50'] = fb['Close'].rolling(50).mean()
print(fb['ma50'])
# Out:
# 0             NaN
# 1             NaN
# 2             NaN
# 3             NaN
# 4             NaN
#           ...
# 775    210.030001
# 776    210.713801
# 777    211.296601
# 778    211.685401
# 779    211.638401
# Name: ma50, Length: 780, dtype: float64

# %%
## Create a new column in the DataFrame using Rolling Window calculation (.rolling()) - Moving average

# %%
fb['Date'] = pd.to_datetime(fb['Date'], format='%Y-%m-%d')  

#plot the moving average
plt.figure(figsize=(10, 8))

fb['ma50'].loc[(fb['Date'] >= '2015-01-01') & (fb['Date']<='2015-12-31')].plot(label='MA50')
fb['Close'].loc[(fb['Date'] >= '2015-01-01') & (fb['Date']<='2015-12-31')].plot(label='Close')
plt.legend()
plt.show()

# %%
# You can use .rolling() to calculate any numbers of days' Moving Average. This is your turn to calculate "60 days"
# moving average of Microsoft, rename it as "ma60". And follow the codes above in plotting a graph
#ms['ma60'] = None
ms['ma60'] = ms['Close'].rolling(50).mean()

#plot the moving average
plt.figure(figsize=(10, 8))
ms['ma60'].loc[(ms['Date'] >= '2015-01-01') & (ms['Date']<='2015-12-31')].plot(label='MA60')
ms['Close'].loc[(ms['Date'] >= '2015-01-01') & (ms['Date']<='2015-12-31')].plot(label='Close')
plt.legend()
plt.show()

# %%
### 1. Munging the stock data and add two columns - MA10 and MA50

# %%
#import FB's stock data, add two columns - MA10 and MA50
#use dropna to remove any "Not a Number" data
fb['MA10'] = fb['Close'].rolling(10).mean()
fb['MA50'] = fb['Close'].rolling(50).mean()
fb = fb.dropna()
fb.head()
# Out:
#          Date       Open       High        Low      Close  Adj Close  \
# 49 2015-03-13  22.559999  22.760000  22.250000  22.700001  22.116024
# 50 2015-03-16  22.879999  23.110001  22.730000  22.969999  22.379078
# 51 2015-03-17  22.920000  23.260000  22.760000  23.250000  22.651876
# 52 2015-03-18  23.250000  23.370001  22.660000  22.870001  22.281652
# 53 2015-03-19  22.950001  23.299999  22.780001  23.219999  22.622650
#
#       Volume  PriceDiff  Direction     ma50    MA10     MA50
# 49   8982200   0.269998          1  21.0174  22.648  21.0174
# 50   5923900   0.280001          1  21.0758  22.685  21.0758
# 51   7497500  -0.379999          0  21.1382  22.792  21.1382
# 52  10337600   0.349998          1  21.1998  22.836  21.1998
# 53   7768900   0.250000          1  21.2804  22.872  21.2804

# %%
### 2. Add "Shares" column to make decisions base on the strategy

# %%
fb['Shares'] = [1 if fb.loc[ei, 'MA10']>fb.loc[ei, 'MA50'] else 0 for ei in fb.index]

# %%
#Add a new column "Profit" using List Comprehension, for any rows in fb, if Shares=1, the profit is calculated as the close price of 
#tomorrow - the close price of today. Otherwise the profit is 0.

#Plot a graph to show the Profit/Loss

fb['Close1'] = fb['Close'].shift(-1)
fb['Profit'] = [fb.loc[ei, 'Close1'] - fb.loc[ei, 'Close'] if fb.loc[ei, 'Shares']==1 else 0 for ei in fb.index]
fb['Profit'].plot()
plt.axhline(y=0, color='red')

# %%
### 3. Use .cumsum() to display our model's performance if we follow the strategy

# %%
#Use .cumsum() to calculate the accumulated wealth over the period

fb['wealth'] = fb['Profit'].cumsum()
fb.tail()
# Out:
#           Date        Open        High         Low       Close   Adj Close  \
# 774 2018-01-29  242.740005  248.110001  240.610001  246.850006  246.850006
# 775 2018-01-30  241.110001  246.419998  238.410004  242.720001  242.720001
# 776 2018-01-31  245.770004  249.270004  244.449997  245.800003  245.800003
# 777 2018-02-01  238.520004  246.899994  238.059998  240.500000  240.500000
# 778 2018-02-02  237.000000  237.970001  231.169998  233.520004  233.520004
#
#        Volume  PriceDiff  Direction        ma50        MA10        MA50  \
# 774  11377900  -4.130005          0  209.375201  233.431003  209.375201
# 775  14270800   3.080002          1  210.030001  235.692003  210.030001
# 776  11964400  -5.300003          0  210.713801  237.800003  210.713801
# 777  12980600  -6.979996          0  211.296601  239.406003  211.296601
# 778  17961600 -19.820007          0  211.685401  239.747003  211.685401
#
#      Shares      Close1    Profit      wealth
# 774       1  242.720001 -4.130005  174.740009
# 775       1  245.800003  3.080002  177.820011
# 776       1  240.500000 -5.300003  172.520008
# 777       1  233.520004 -6.979996  165.540012
# 778       1         NaN       NaN         NaN

# %%
#plot the wealth to show the growth of profit over the period

fb['wealth'].plot()
plt.title('Total money you win is {}'.format(fb.loc[fb.index[-2], 'wealth']))
# Out:
# Text(0.5, 1.0, 'Total money you win is 165.54001200000002')
